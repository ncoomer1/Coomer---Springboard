# %% [markdown]
# # Exploratory Data Analysis

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)

# %%
maternal_health=pd.read_csv(r"C:\Users\nicol\Desktop\Capstone 2 - Data Wrangling\Maternal Health Risk Data Set.csv")

# %%
maternal_health.shape
# Out:
# (1014, 7)

# %%
maternal_health.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1014 entries, 0 to 1013
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          1014 non-null   int64
#  1   SystolicBP   1014 non-null   int64
#  2   DiastolicBP  1014 non-null   int64
#  3   BS           1014 non-null   float64
#  4   BodyTemp     1014 non-null   float64
#  5   HeartRate    1014 non-null   int64
#  6   RiskLevel    1014 non-null   object
# dtypes: float64(2), int64(4), object(1)
# memory usage: 55.6+ KB

# %%
maternal_health.head()
# Out:
#    Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate  RiskLevel
# 0   25         130           80  15.0      98.0         86  high risk
# 1   35         140           90  13.0      98.0         70  high risk
# 2   29          90           70   8.0     100.0         80  high risk
# 3   30         140           85   7.0      98.0         70  high risk
# 4   35         120           60   6.1      98.0         76   low risk

# %%
#Summary of data
maternal_health.describe().T
# Out:
#               count        mean        std   min    25%    50%    75%    max
# Age          1014.0   29.871795  13.474386  10.0   19.0   26.0   39.0   70.0
# SystolicBP   1014.0  113.198225  18.403913  70.0  100.0  120.0  120.0  160.0
# DiastolicBP  1014.0   76.460552  13.885796  49.0   65.0   80.0   90.0  100.0
# BS           1014.0    8.725986   3.293532   6.0    6.9    7.5    8.0   19.0
# BodyTemp     1014.0   98.665089   1.371384  98.0   98.0   98.0   98.0  103.0
# HeartRate    1014.0   74.301775   8.088702   7.0   70.0   76.0   80.0   90.0

# %%
#Summary of categorical data
maternal_health.describe(include=["O"])
# Out:
#        RiskLevel
# count       1014
# unique         3
# top     low risk
# freq         406

# %%
#
hist = maternal_health.hist(bins=10,figsize =(10,10))

# %%
#Boxplot to identify any outliers
boxplot = maternal_health.boxplot(grid=False, vert=False,fontsize=15)

# %%
#Correlation matrix heat map
plt.figure(figsize=(14,12))
sns.heatmap(maternal_health.corr(),linewidths=.1,cmap="YlGnBu", annot=True)
plt.yticks(rotation=0);

# %% [markdown]
# Relationships appear to exist between blood gluclose level (BS) and age, as well as systolic blood pressure and age, and diastolic blood pressure and age. Strong relationships also appear between systolic and diastolic blood pressure.

# %%
#pair plots
g = sns.pairplot(maternal_health)

# %% [markdown]
# # Modeling

# %% [markdown]
# Since datasets were labeled, I opted to use supervised learning techniques of linear regression and classification.

# %% [markdown]
# # Non Linear Regression model

# %%
import numpy as num
import pandas as pds
import matplotlib.pyplot as plot
maternal_health=pd.read_csv(r"C:\Users\nicol\Desktop\Capstone 2 - Data Wrangling\Maternal Health Risk Data Set.csv")
maternal_health.head(10)
plot.figure(figsize=(8,5))
x_data, y_data = (maternal_health["Age"].values, maternal_health["HeartRate"].values)
plot.plot(x_data, y_data, 'ro')
plot.ylabel('Age')
plot.xlabel('HeartRate')
plot.show()

# %%
import pandas
from sklearn import tree
import pydotplus
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
import matplotlib.image as pltimg

maternal_health=pd.read_csv(r"C:\Users\nicol\Desktop\Capstone 2 - Data Wrangling\Maternal Health Risk Data Set.csv")

# %%
print(maternal_health)
# Out:
#       Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate  RiskLevel
# 0      25         130           80  15.0      98.0         86  high risk
# 1      35         140           90  13.0      98.0         70  high risk
# 2      29          90           70   8.0     100.0         80  high risk
# 3      30         140           85   7.0      98.0         70  high risk
# 4      35         120           60   6.1      98.0         76   low risk
# ...   ...         ...          ...   ...       ...        ...        ...
# 1009   22         120           60  15.0      98.0         80  high risk
# 1010   55         120           90  18.0      98.0         60  high risk
# 1011   35          85           60  19.0      98.0         86  high risk
# 1012   43         120           90  18.0      98.0         70  high risk
# 1013   32         120           65   6.0     101.0         76   mid risk
#
# [1014 rows x 7 columns]

# %%
d = {'High Risk': high risk, 'Mid Risk': mid risk, 'Low Risk': low risk}
maternal_health['Risk Level'] = maternal_health['Risk Level'].map(d)

features = ['Age', 'Systolic BP', 'Diastolic BP', 'Blood Glucose', 'Body Temp', 'Heart Rate', 'Risk Level']

X = maternal_health[features]
y = maternal_health[d]

dtree = DecisionTreeClassifier()
dtree = dtree.fit(X, y)
data = tree.export_graphviz(dtree, out_file=None, feature_names=features)
graph = pydotplus.graph_from_dot_data(data)
graph.write_png('mydecisiontree.png')

img=pltimg.imread('mydecisiontree.png')
imgplot = plt.imshow(img)
plt.show()
# Out:
#   File "C:\Users\nicol\AppData\Local\Temp/ipykernel_15788/1697547217.py", line 1
#     d = {'High Risk': high risk, 'Mid Risk': mid risk, 'Low Risk': low risk}
#                            ^
# SyntaxError: invalid syntax

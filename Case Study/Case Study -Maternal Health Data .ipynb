# %%
#Imports
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
#load data
maternal_health = pd.read_csv(r"C:\Users\nicol\Desktop\Maternal Health Risk Data Set.csv")

# %%
maternal_health
# Out:
#       Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate  RiskLevel
# 0      25         130           80  15.0      98.0         86  high risk
# 1      35         140           90  13.0      98.0         70  high risk
# 2      29          90           70   8.0     100.0         80  high risk
# 3      30         140           85   7.0      98.0         70  high risk
# 4      35         120           60   6.1      98.0         76   low risk
# ...   ...         ...          ...   ...       ...        ...        ...
# 1009   22         120           60  15.0      98.0         80  high risk
# 1010   55         120           90  18.0      98.0         60  high risk
# 1011   35          85           60  19.0      98.0         86  high risk
# 1012   43         120           90  18.0      98.0         70  high risk
# 1013   32         120           65   6.0     101.0         76   mid risk
#
# [1014 rows x 7 columns]

# %%
#Review of first several rows of data
maternal_health.head()
# Out:
#    Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate  RiskLevel
# 0   25         130           80  15.0      98.0         86  high risk
# 1   35         140           90  13.0      98.0         70  high risk
# 2   29          90           70   8.0     100.0         80  high risk
# 3   30         140           85   7.0      98.0         70  high risk
# 4   35         120           60   6.1      98.0         76   low risk

# %%
#Missing values by column
missing = pd.concat([maternal_health.isnull().sum(), 100 * maternal_health.isnull().mean()], axis=1)
missing.columns=['count', '%']
missing.sort_values(by=['count', '%'])
# Out:
#              count    %
# Age              0  0.0
# SystolicBP       0  0.0
# DiastolicBP      0  0.0
# BS               0  0.0
# BodyTemp         0  0.0
# HeartRate        0  0.0
# RiskLevel        0  0.0

# %% [markdown]
# No values are missing.

# %%
#'dtypes' by object
maternal_health['Age'].value_counts().head()
# Out:
# 23    71
# 19    67
# 17    63
# 15    60
# 35    50
# Name: Age, dtype: int64

# %%
#Description of data
maternal_health.describe().T
# Out:
#               count        mean        std   min    25%    50%    75%    max
# Age          1014.0   29.871795  13.474386  10.0   19.0   26.0   39.0   70.0
# SystolicBP   1014.0  113.198225  18.403913  70.0  100.0  120.0  120.0  160.0
# DiastolicBP  1014.0   76.460552  13.885796  49.0   65.0   80.0   90.0  100.0
# BS           1014.0    8.725986   3.293532   6.0    6.9    7.5    8.0   19.0
# BodyTemp     1014.0   98.665089   1.371384  98.0   98.0   98.0   98.0  103.0
# HeartRate    1014.0   74.301775   8.088702   7.0   70.0   76.0   80.0   90.0

# %%
#Since it appears that no variables are missing, we will move on to examining distributions of feature variables.
maternal_health.plot.hist(15,10)
plt.subplots_adjust(hspace=0.5)

# %% [markdown]
# # Summary

# %% [raw]
# - Do your column names correspond to what those columns
# store?
#
# Yes.
#
# - Check the data types of your columns. Are they sensible?
#
# Yes.
#
# - Calculate summary statistics for each of your columns, such
# as mean, median, mode, standard deviation, range, and
# number of unique values. What does this tell you about your
# data? What do you now need to investigate?
#
# Data actually appears to be quite clean. There are no missing variables. Columns fall in ranges that appear to be reasonable. Data set is ready for next step of data science process.
